# %% [markdown]
# [595_Big_Countries](https://leetcode.com/problems/big-countries/description/)

# %%
# %run "../utils"

# %%
world_input = """| name        | continent | area    | population | gdp          |
| ----------- | --------- | ------- | ---------- | ------------ |
| Afghanistan | Asia      | 652230  | 25500100   | 20343000000  |
| Albania     | Europe    | 28748   | 2831741    | 12960000000  |
| Algeria     | Africa    | 2381741 | 37100000   | 188681000000 |
| Andorra     | Europe    | 468     | 78115      | 3712000000   |
| Angola      | Africa    | 1246700 | 20609294   | 100990000000 |"""
expected_output = """| name        | population | area    |
| ----------- | ---------- | ------- |
| Afghanistan | 25500100   | 652230  |
| Algeria     | 37100000   | 2381741 |"""

# %%
world_df = create_df_from_leetcode_input(world_input)
expected_output_df = create_df_from_leetcode_input(expected_output)

# %%
min_area = 3000000
min_population = 25000000
output_df = world_df.filter(f"(area >= {min_area}) or (population >= {min_population})")\
    .select("name", "population", "area")

# %%
check_acceptance(output_df, expected_output_df)
# Out:
#  🙌 ACCEPTED 🙌
