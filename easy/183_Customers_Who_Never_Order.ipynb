# %% [markdown]
# [183_Customers_Who_Never_Order](https://leetcode.com/problems/customers-who-never-order/description/)

# %%
# %run "../utils"

# %%
customers_input = """| id | name  |
| -- | ----- |
| 1  | Joe   |
| 2  | Henry |
| 3  | Sam   |
| 4  | Max   |"""
orders_input = """| id | customerId |
| -- | ---------- |
| 1  | 3          |
| 2  | 1          |"""
expected_output = """| Customers |
| --------- |
| Henry     |
| Max       |"""

# %%
customers_df = create_df_from_leetcode_input(customers_input)
orders_df = create_df_from_leetcode_input(orders_input)
expected_output_df = create_df_from_leetcode_input(expected_output)

# %%
output_df = customers_df.join(orders_df, customers_df.id == orders_df.customerId, "left_anti").select("name")

# %%
check_acceptance(output_df, expected_output_df)
# Out:
#  🙌 ACCEPTED 🙌
