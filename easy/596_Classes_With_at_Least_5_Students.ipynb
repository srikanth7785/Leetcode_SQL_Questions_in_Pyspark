# %% [markdown]
# [596_Classes_With_at_Least_5_Students](https://leetcode.com/problems/classes-with-at-least-5-students/description/)

# %%
# %run "../utils"

# %%
courses_input = """| student | class    |
| ------- | -------- |
| A       | Math     |
| B       | English  |
| C       | Math     |
| D       | Biology  |
| E       | Math     |
| F       | Computer |
| G       | Math     |
| H       | Math     |
| I       | Math     |"""
expected_output = """| class |
| ----- |
| Math  |"""

# %%
courses_df = create_df_from_leetcode_input(courses_input)
expected_output_df = create_df_from_leetcode_input(expected_output)

# %%
output_df = courses_df.groupBy("class")\
    .agg(F.count("student").alias("cnt"))\
        .filter("cnt >= 5")\
            .select("class")

# %%
check_acceptance(output_df, expected_output_df)
# Out:
#  🙌 ACCEPTED 🙌
